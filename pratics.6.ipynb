# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. Create an Advanced DataFrame
# This example creates a DataFrame with multiple data types and a time series index.
data = {
    'Category': np.random.choice(['A', 'B', 'C', 'D'], 100),
    'Value1': np.random.rand(100) * 100,
    'Value2': np.random.randint(1, 50, 100),
    'Date': pd.to_datetime(pd.date_range(start='2023-01-01', periods=100, freq='D'))
}
df = pd.DataFrame(data)
df = df.set_index('Date') # Set 'Date' as the index for time-series plotting

# 2. Create various graphs from the DataFrame

# Line plot of 'Value1' over time
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Value1'])
plt.title('Value1 Over Time')
plt.xlabel('Date')
plt.ylabel('Value1')
plt.grid(True)
plt.show()

# Bar plot of the count of each 'Category'
category_counts = df['Category'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(category_counts.index, category_counts.values)
plt.title('Count of Each Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# Scatter plot of 'Value1' vs 'Value2'
plt.figure(figsize=(8, 6))
plt.scatter(df['Value1'], df['Value2'], alpha=0.7)
plt.title('Value1 vs Value2')
plt.xlabel('Value1')
plt.ylabel('Value2')
plt.show()

# Histogram of 'Value1'
plt.figure(figsize=(8, 5))
plt.hist(df['Value1'], bins=10, edgecolor='black')
plt.title('Distribution of Value1')
plt.xlabel('Value1')
plt.ylabel('Frequency')
plt.show()

# Box plot of 'Value1' by 'Category'
plt.figure(figsize=(10, 6))
df.boxplot(column='Value1', by='Category')
plt.title('Value1 Distribution by Category')
plt.suptitle('') # Suppress the default suptitle created by boxplot
plt.xlabel('Category')
plt.ylabel('Value1')
plt.show()

# pi graph
import matplotlib .pyplot as plt
# Data
labels = ['Apple','Bannana','Mango','Orange']
sizes = [30, 15, 25, 30]
# plot
plt.pie(sizes, labels=labels,  autopct='%1.1f%%', startangle=90)
plt.title("Fruit Distribution Pie Chart")
plt.show()


# Customized Histogram with Watermark
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Creating dataset
np.random.seed(23685752)
N_points = 10000
n_bins = 20
# Creating distribution
x = np.random.randn(N_points)
y = 0.8 ** x + np.random.randn(N_points) + 25
legend = ['distribution']
# Creating figure and axes
fig, axs = plt.subplots(1, 1, figsize=(10, 7), tight_layout=True)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)
# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')
# Add padding between axes and labels
axs.xaxis.set_tick_params(pad=5)
axs.yaxis.set_tick_params(pad=10)
# Add x, y gridlines (updated syntax)
axs.grid(visible=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.6)
# Add text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30',
         fontsize=12,
         color='red',
         ha='right',
         va='bottom',
         alpha=0.7)
# Creating histogram
N, bins, patches = axs.hist(x, bins=n_bins)
# Setting color gradient
fracs = ((N ** (1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)
# Adding extra features
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(legend)
plt.title('Customized Histogram with Watermark')
# Show plot
plt.show()

# stacked Histogram chart
import matplotlib.pyplot as plt
import numpy as np
data1 = np.random.randn(1000) 
data2 = np.random.normal(loc=3, scale=1, size=1000)
plt.hist([data1,data2], bins=30,stacked=True,color=['cyan','purple'],edgecolor='black')
plt.xlabel('values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')
plt.legend(['Dataset 1','Dataset 2'])
plt.show()

# basic histogram
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=30, color='skyblue',edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic histogram')
plt.show()

# hitstogram 1, histogram 2
import matplotlib.pyplot as plt
import numpy as np
# Generate random data for multiple histograms
data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)
# Creating subplots with multiple histograms
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
axes[0].hist(data1, bins=30, color='Yellow', edgecolor='black')
axes[0].set_title('Histogram 1')
axes[1].hist(data2, bins=30, color='Pink', edgecolor='black')
axes[1].set_title('Histogram 2')
# Adding labels and title
for ax in axes:
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')
# Adjusting layout for better spacing
plt.tight_layout()
# Display the figure
plt.show()

# 2D Histogram
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
y = 2 * x + np.random.normal(size=1000)
plt.hexbin(x, y, gridsize=30, cmap='Blues')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('2D Histogram (Hexbin plot)')
plt.colorbar(label='counts')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 11
#       3 import numpy as np
#       5 # 1. Create an Advanced DataFrame
#       6 # This example creates a DataFrame with multiple data types and a time series index.
#       7 data = {
#       8     'Category': np.random.choice(['A', 'B', 'C', 'D'], 100),
#       9     'Value1': np.random.rand(100) * 100,
#      10     'Value2': np.random.randint(1, 50, 100),
# ---> 11     'Date': pd.to_datetime(pd.date_range(start='2023-01-01', periods=100, freq='D'))
#      12 }
#      13 df = pd.DataFrame(data)
#      14 df = df.set_index('Date') # Set 'Date' as the index for time-series plotting
#
# AttributeError: module 'pandas' has no attribute 'to_datetime'

# %%
# Customized Histogram with Watermark
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Creating dataset
np.random.seed(23685752)
N_points = 10000
n_bins = 20
# Creating distribution
x = np.random.randn(N_points)
y = 0.8 ** x + np.random.randn(N_points) + 25
legend = ['distribution']
# Creating figure and axes
fig, axs = plt.subplots(1, 1, figsize=(10, 7), tight_layout=True)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)
# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')
# Add padding between axes and labels
axs.xaxis.set_tick_params(pad=5)
axs.yaxis.set_tick_params(pad=10)
# Add x, y gridlines (updated syntax)
axs.grid(visible=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.6)
# Add text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30',
         fontsize=12,
         color='red',
         ha='right',
         va='bottom',
         alpha=0.7)
# Creating histogram
N, bins, patches = axs.hist(x, bins=n_bins)
# Setting color gradient
fracs = ((N ** (1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)
# Adding extra features
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(legend)
plt.title('Customized Histogram with Watermark')
# Show plot
plt.show()

# stacked Histogram chart
import matplotlib.pyplot as plt
import numpy as np
data1 = np.random.randn(1000) 
data2 = np.random.normal(loc=3, scale=1, size=1000)
plt.figure(figsize=(15,10))
plt.hist([data1,data2], bins=30,stacked=True,color=['cyan','purple'],edgecolor='black')
plt.xlabel('values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')
plt.legend(['Dataset 1','Dataset 2'])
plt.show()

# basic histogram
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=30, color='skyblue',edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic histogram')
plt.show()

# hitstogram 1, histogram 2
import matplotlib.pyplot as plt
import numpy as np
# Generate random data for multiple histograms
data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)
# Creating subplots with multiple histograms
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
axes[0].hist(data1, bins=30, color='Yellow', edgecolor='black')
axes[0].set_title('Histogram 1')
axes[1].hist(data2, bins=30, color='Pink', edgecolor='black')
axes[1].set_title('Histogram 2')
# Adding labels and title
for ax in axes:
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')
# Adjusting layout for better spacing
plt.tight_layout()
# Display the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
plt.figure(figsize=(10,7))
plt.hist(data, bins=30, color='blue', edgecolor='black' )
plt.title('sales of salary')
plt.xlabel('sales')
plt.ylabel('salary')
plt.show()

# %%
# stacked Histogram chart
import matplotlib.pyplot as plt
import numpy as np
data1 = np.random.randn(1000) 
data2 = np.random.normal(loc=3, scale=1, size=1000)
plt.figure(figsize=(6,5))
plt.hist([data1,data2], bins=30,stacked=True,color=['skyblue','purple'],edgecolor='black')
plt.xlabel('values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')
plt.legend(['Dataset 1','Dataset 2'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)
plt.figure(figsize=(10,6))
plt.hist([data1,data2], bins=30, stacked=True, color=['purple','blue'], edgecolor='black')
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('staked histogram')
plt.legend(['dataset 1','dataset 2'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)
plt.figure(figsize=(10,6))
plt.hist([data1,data2], bins=30, stacked=True, color=['purple','red'], edgecolor='black')
plt.title('stacked histogram')
plt.xlabel('value')
plt.ylabel('frequency')
plt.legend(['dataset 1', 'dataset 2'])
plt.show()

# %%
# Customized Histogram with Watermark
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Creating dataset
np.random.seed(23685752)
N_points = 10000
n_bins = 20
# Creating distribution
x = np.random.randn(N_points)
y = 0.8 ** x + np.random.randn(N_points) + 25
legend = ['distribution']
# Creating figure and axes
fig, axs = plt.subplots(1, 1, figsize=(10,6), tight_layout=True)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    axs.spines[s].set_visible(False)
# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')
# Add padding between axes and labels
axs.xaxis.set_tick_params(pad=5)
axs.yaxis.set_tick_params(pad=10)
# Add x, y gridlines (updated syntax)
axs.grid(visible=True, color='black', linestyle='-.', linewidth=0.5, alpha=0.6)
# Add text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30',
         fontsize=12,
         color='red',
         ha='right',
         va='bottom',
         alpha=0.7)
# Creating histogram
N, bins, patches = axs.hist(x, bins=n_bins)
# Setting color gradient
fracs = ((N ** (1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)
# Adding extra features
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(legend)
plt.title('Customized Histogram with Watermark')
# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)
data3 = np.random.normal(loc=2, scale=1, size=1000)
plt.figure(figsize=(10,7))
plt.hist([data1,data2,data3], bins=30, stacked=True, color=['purple','red','green'], edgecolor='black')
plt.title('stacked histogram')
plt.xlabel('value')
plt.ylabel('frequency')
plt.legend(['dataset 1', 'dataset 2','dataset 3'])
plt.show()

# %%
# hitstogram 1, histogram 2
import matplotlib.pyplot as plt
import numpy as np
# Generate random data for multiple histograms
data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)
# Creating subplots with multiple histograms
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(4,2))
axes[0].hist(data1, bins=30, color='Yellow', edgecolor='black')
axes[0].set_title('Histogram 1')
axes[1].hist(data2, bins=30, color='Pink', edgecolor='black')
axes[1].set_title('Histogram 2')
# Adding labels and title
for ax in axes:
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')
# Adjusting layout for better spacing
plt.tight_layout()
# Display the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1=np.random.randn(1000)
data2=np.random.normal(loc=1, scale=1, size=1000)
data3=np.random.normal(loc=1, scale=1, size=1000)
data4=np.random.normal(loc=1, scale=1, size=1000)
data5=np.random.normal(loc=1, scale=1, size=1000)
plt.figure(figsize=(20,10))
plt.hist([data1,data2,data3,data4],bins=200, stacked=True, color=['red','green','blue','purple'], edgecolor='black' )
plt.title('stacksd Histogram')
plt.xlabel('value')
plt.ylabel('frequency')
plt.legend(['data1','data2','data3','data4'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1=np.random.randn(1000)
data2=np.random.normal(loc=1, scale=1, size=1000)
data3=np.random.normal(loc=1, scale=1, size=1000)
data4=np.random.normal(loc=1, scale=1, size=1000)
data5=np.random.normal(loc=1, scale=1, size=1000)
data6=np.random.normal(loc=1, scale=1, size=1000)
fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(30,15)) 

plt.hist([data1,data2,data3,data4],bins=200, stacked=True, color=['red','green','blue','purple'], edgecolor='black' )
plt.title('stacksd Histogram')
plt.xlabel('value')
plt.ylabel('frequency')
plt.legend(['data1','data2','data3','data4'])
plt.show()

axes[0].hist(data1, bins=40, color='red', edgecolor='black')
axes[0].set_title('Histogram 1')
axes[1].hist(data2, bins=40, color='blue', edgecolor='black')
axes[1].set_title('Histogram 2')
axes[2].hist(data3, bins=40, color='green', edgecolor='black')
axes[2].set_title('Histogram 3')
axes[3].hist(data4, bins=40, color='purple', edgecolor='black')
axes[3].set_title('Histogram 4')
axes[4].hist(data5, bins=40, color='orange', edgecolor='black')
axes[4].set_title('Histogram 5')
axes[5].hist(data6, bins=40, color='pink', edgecolor='black')
axes[5].set_title('Histogram 6')
for ax in axes:
    ax.set_xlabel('value')
    ax.set_ylabel('frquency')
    plt.tight_layout
    
    plt.show()

# %%
# hitstogram 1, histogram 2
import matplotlib.pyplot as plt
import numpy as np
# Generate random data for multiple histograms
data1 = np.random.randn(1000)
data2 = np.random.normal(loc=3, scale=1, size=1000)
data3 = np.random.normal(loc=4, scale=1, size=1000)
data4 = np.random.normal(loc=4, scale=1, size=1000)
# Creating subplots with multiple histograms
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15,7))
axes[0].hist(data1, bins=30, color='red', edgecolor='black')
axes[0].set_title('Histogram 1')
axes[1].hist(data2, bins=30, color='blue', edgecolor='black')
axes[1].set_title('Histogram 2')
axes[2].hist(data3, bins=30, color='Purple', edgecolor='black')
axes[2].set_title('Histogram 3')
axes[3].hist(data4, bins=30, color='green', edgecolor='black')
axes[3].set_title('Histogram 4')
# Adding labels and title
for ax in axes:
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')
# Adjusting layout for better spacing
plt.tight_layout()
# Display the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
plt.figure(figsize=(10,7))
plt.hist(data, bins=30, color='blue', edgecolor='black' )
plt.title('sales of salary')
plt.xlabel('sales')
plt.ylabel('salary')
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
data1=np.random.randn(1000)
data2=np.random.normal(loc=1, scale=1, size=1000 )
data3=np.random.normal(loc=1, scale=1, size=1000 )
data4=np.random.normal(loc=1, scale=1, size=1000 )
plt.figure(figsize=(10,6))
plt.hist([data1,data2,data3,data4], bins=30, stacked=True, color=['red','green','blue','purple'], edgecolor='black' )
plt.hist([data1,data2,data3,data4], bins=30, stacked=True, color=['red','green','purple','blue'], edgecolor='black')
plt.title('shacked Histogram')
plt.xlabel('value')
plt.ylabel('frequency')
plt.legend(['data1','data2','data3','data4'])
plt.show()

# %%
import matplotlib.pyplot as plt
year=['january','febry','march','aprial','may','jun','july','augist','setember','october','november','december']
storeA=[300,400,500,600,700,800,900,1000,2000,3000,4000,5000]

plt.figure(figsize=(10,6))
plt.plot(storeA, color='blue', marker='o', linestyle='--')
plt.title('advance line style')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
import matplotlib.pyplot as plt

year=['january','febry','march','aprial','may','jun','july','augist','setember','october','november','december']
storeA=[7000,400,500,600,7000,800,900,1000,2000,3000,4000,9000]
storeB=[6000,300,400,800,7000,900,100,1000,2000,7000,1000,8000]
storeC=[6000,300,400,400,5000,900,500,2000,2000,4000,1000,7000]
storeD=[4000,300,400,500,7000,500,100,1000,5000,7000,1000,5000]

plt.figure(figsize=(15,10))
plt.plot(storeA, color='blue', marker='o', linestyle='--')
plt.plot(storeB, color='green', marker='o', linestyle='--')
plt.plot(storeC, color='yellow', marker='o', linestyle='--')
plt.plot(storeD, color='purple', marker='o', linestyle='--')
plt.title('Microsoft Amazone IBM Tesla COMPNYIES profit line graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
a=['years','storeA','storeB','storeC','storeD']
plt.legend(a)
plt.show()

# %%
import matplotlib.pyplot as plt                    
Days=['Mon','Tue','Wed','Thu','fri','sat','sun']
storeA=[202,303,406,450,320,430,210]
storeB=[250,300,350,260,450,100,350]
plt.figure(figsize=(5,5))
plt.plot(storeA,color="b",marker="+")
plt.plot(storeB,color="red",linestyle="--",marker="o")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
a=["Days","storeA","storeB"]
plt.legend(a)
plt.title("Line Chart")
plt.show()

# %%
# basic histogram
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
plt.figure(figsize=(10,7))
plt.hist(data, bins=30, color='skyblue',edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic histogram')
plt.show()

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
sales = [2000, 3000, 4000]
salary = [2500, 2600, 3400]
plt.figure(figsize=(10,6))
plt.plot(sales, salary, color='blue', marker='o', linestyle='-')
plt.title('sales of salary')
plt.xlabel('sales')
plt.ylabel('salary')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
data
#sns.barplot(x='day', y='total_bill',data=data,ci=None)
#sns.countplot(x='sex',data=data,hue'smoker',paiette='hot')
#data
#sns.boxplot(x='day',y='tip',data=data,palette='hot')
#sns.violinplot(x='day',y='sex',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
sns.stripplot(x='day',y='total_bill',data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
data
#sns.barplot(x='day', y='total_bill',data=data,ci=None)
#sns.countplot(x='sex',data=data,hue'smoker',paiette='hot')
#data
#sns.boxplot(x='day',y='tip',data=data,palette='hot')
#sns.violinplot(x='day',y='sex',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# Out:
# C:\Users\vishnu\AppData\Local\Temp\ipykernel_27736\3167368288.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
data
#sns.barplot(x='day', y='total_bill',data=data,ci=None)
#sns.countplot(x='sex',data=data,hue'smoker',paiette='hot')
#data
#sns.boxplot(x='day',y='tip',data=data,palette='hot')
#sns.violinplot(x='day',y='sex',data=data,palette='hot')
sns.stripplot(x='day',y='total_bill',data=data)
# sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
data
#sns.barplot(x='day', y='total_bill',data=data,ci=None)
#sns.countplot(x='sex',data=data,hue'smoker',paiette='hot')
#data
#sns.boxplot(x='day',y='tip',data=data,palette='hot')
sns.violinplot(x='day',y='sex',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# Out:
# C:\Users\vishnu\AppData\Local\Temp\ipykernel_27736\2370289078.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day',y='sex',data=data,palette='hot')
# <Axes: xlabel='day', ylabel='sex'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
data
#sns.barplot(x='day', y='total_bill',data=data,ci=None)
#sns.countplot(x='sex',data=data,hue'smoker',paiette='hot')
#data
sns.boxplot(x='day',y='tip',data=data,palette='hot')
#sns.violinplot(x='day',y='sex',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# Out:
# C:\Users\vishnu\AppData\Local\Temp\ipykernel_27736\3044941100.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='tip',data=data,palette='hot')
# <Axes: xlabel='day', ylabel='tip'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
data
#sns.barplot(x='day', y='total_bill',data=data,ci=None)
sns.countplot(x='sex',data=data,hue='smoker',palette='hot')
#data
#sns.boxplot(x='day',y='tip',data=data,palette='hot')
#sns.violinplot(x='day',y='sex',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
data
sns.barplot(x='day', y='total_bill',data=data,ci=None)
#sns.countplot(x='sex',data=data,hue'smoker',paiette='hot')
#data
#sns.boxplot(x='day',y='tip',data=data,palette='hot')
#sns.violinplot(x='day',y='sex',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# sns.pointplot(x='day',y='total_bill',data=data,palette='hot')
# sns.stripplot(x='day',y='total_bill',data=data)
# Out:
# C:\Users\vishnu\AppData\Local\Temp\ipykernel_27736\602599285.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='day', y='total_bill',data=data,ci=None)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import pandas as pd
# import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data= sns.load_dataset('tips')
pivot = data.pivot_table(value='total_bill', index='day',colmns='sex',aggffunc='mean')

sns.heatmap(pivot,cmap='Purples',annot=True)
pivot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       4 import matplotlib.pyplot as plt
#       6 data= sns.load_dataset('tips')
# ----> 7 pivot = data.pivot_table(value='total_bill', index='day',colmns='sex',aggffunc='mean')
#       9 sns.heatmap(pivot,cmap='Purples',annot=True)
#      10 pivot
#
# TypeError: DataFrame.pivot_table() got an unexpected keyword argument 'value'. Did you mean 'values'?
